# %%
# %matplotlib inline
import import_ipynb
from RL_model import RL_model
import os
import gym
import torch as th
import numpy as np
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
from stable_baselines3 import DQN
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
# Out:
# importing Jupyter notebook from RL_model.ipynb
# importing Jupyter notebook from SV_channel.ipynb
# Covariance matrix:
#  [[ 1.8122+0.j     -0.1958-0.9854j -1.0798+0.6929j -0.9312+0.1586j]
#  [-0.1958+0.9854j  1.9834+0.j     -0.7396-1.175j  -0.4602+0.0377j]
#  [-1.0798-0.6929j -0.7396+1.175j   1.5417+0.j      0.5278-0.1983j]
#  [-0.9312-0.1586j -0.4602-0.0377j  0.5278+0.1983j  0.9394+0.j    ]]
#
# Matrix rank: 4
# importing Jupyter notebook from HybridMassiveMIMO.ipynb
# Channel capacity estimation for SNR 70 dB: 11.198521824187482 bps/Hz

# %%
qam16_gray = {"0000": np.complex128(-3 + 3j), "0001": np.complex128(-3 + 1j), "0010": np.complex128(-3 - 3j), \
              "0011": np.complex128(-3 - 1j), "0100": np.complex128(-1 + 3j), "0101": np.complex128(-1 + 1j), \
              "0110": np.complex128(-1 - 3j), "0111": np.complex128(-1 - 1j), "1000": np.complex128(3 + 3j), \
              "1001": np.complex128(3 + 1j), "1010": np.complex128(3 - 3j), "1011": np.complex128(3 - 1j), \
              "1100": np.complex128(1 + 3j), "1101": np.complex128(1 + 1j), "1110": np.complex128(1 - 3j), \
              "1111": np.complex128(1 - 1j)}

# Training by DQN
env = RL_model(N_s = 4,
                N_rf = 4,
                N_tx = (4, 4),
                N_rx = (2, 2),
                N_ofdm = 4,
                N_ifft = 512,
                N_c = 450,
                N_gi = 64,
                mapping = qam16_gray,
                N_p = 4,
                static_chan = False,
                SNR = (70, 70),
                cl = 5,
                rays = 2,
                reward_param = 5)
env.reset()

models_dir = "models/DQN1"
logdir = "logs"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

time_steps = 20000

model = DQN.load(f"{models_dir.replace('1', '0')}/10000")

model.set_env(env)

model.learn(total_timesteps = time_steps, tb_log_name = "DQN1", reset_num_timesteps = False)

model.save(f"{models_dir}/{time_steps}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\DQN1_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 11       |
# |    time_elapsed     | 18       |
# |    total_timesteps  | 10215    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.252    |
# |    n_updates        | 92       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 13       |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 10624    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0165   |
# |    n_updates        | 96       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 14       |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 10916    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0316   |
# |    n_updates        | 99       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | 11.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 14       |
# |    time_elapsed     | 99       |
# |    total_timesteps  | 11463    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.187    |
# |    n_updates        | 104      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 14       |
# |    time_elapsed     | 140      |
# |    total_timesteps  | 12067    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.12     |
# |    n_updates        | 110      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 148      |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 14       |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 12460    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.113    |
# |    n_updates        | 114      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 144      |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 14       |
# |    time_elapsed     | 185      |
# |    total_timesteps  | 12729    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.106    |
# |    n_updates        | 117      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 142      |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 14       |
# |    time_elapsed     | 209      |
# |    total_timesteps  | 13091    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.178    |
# |    n_updates        | 120      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 141      |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 14       |
# |    time_elapsed     | 240      |
# |    total_timesteps  | 13533    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.018    |
# |    n_updates        | 125      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 14       |
# |    time_elapsed     | 249      |
# |    total_timesteps  | 13666    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0303   |
# |    n_updates        | 126      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 134      |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 14       |
# |    time_elapsed     | 262      |
# |    total_timesteps  | 13851    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.143    |
# |    n_updates        | 128      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 123      |
# |    ep_rew_mean      | 11.1     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 14       |
# |    time_elapsed     | 285      |
# |    total_timesteps  | 14185    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.204    |
# |    n_updates        | 131      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 14       |
# |    time_elapsed     | 295      |
# |    total_timesteps  | 14317    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.237    |
# |    n_updates        | 133      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 14       |
# |    time_elapsed     | 307      |
# |    total_timesteps  | 14483    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.141    |
# |    n_updates        | 134      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 14       |
# |    time_elapsed     | 327      |
# |    total_timesteps  | 14780    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.233    |
# |    n_updates        | 137      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 14       |
# |    time_elapsed     | 363      |
# |    total_timesteps  | 15290    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.198    |
# |    n_updates        | 142      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 124      |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 14       |
# |    time_elapsed     | 442      |
# |    total_timesteps  | 16457    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0794   |
# |    n_updates        | 154      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 14       |
# |    time_elapsed     | 463      |
# |    total_timesteps  | 16774    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0263   |
# |    n_updates        | 157      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 115      |
# |    ep_rew_mean      | 10.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 14       |
# |    time_elapsed     | 486      |
# |    total_timesteps  | 17128    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0356   |
# |    n_updates        | 161      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 105      |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 14       |
# |    time_elapsed     | 503      |
# |    total_timesteps  | 17370    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0685   |
# |    n_updates        | 163      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.8     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 14       |
# |    time_elapsed     | 553      |
# |    total_timesteps  | 18109    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.152    |
# |    n_updates        | 171      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 89.8     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 14       |
# |    time_elapsed     | 560      |
# |    total_timesteps  | 18216    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.193    |
# |    n_updates        | 172      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.1     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 14       |
# |    time_elapsed     | 582      |
# |    total_timesteps  | 18525    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.258    |
# |    n_updates        | 175      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 90.6     |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 14       |
# |    time_elapsed     | 612      |
# |    total_timesteps  | 18944    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.258    |
# |    n_updates        | 179      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97.8     |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 14       |
# |    time_elapsed     | 666      |
# |    total_timesteps  | 19784    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.109    |
# |    n_updates        | 187      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 100      |
# |    ep_rew_mean      | 10.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 14       |
# |    time_elapsed     | 695      |
# |    total_timesteps  | 20227    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.335    |
# |    n_updates        | 192      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 14       |
# |    time_elapsed     | 731      |
# |    total_timesteps  | 20795    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.232    |
# |    n_updates        | 197      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 102      |
# |    ep_rew_mean      | 10.8     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 14       |
# |    time_elapsed     | 749      |
# |    total_timesteps  | 21066    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.179    |
# |    n_updates        | 200      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 99.2     |
# |    ep_rew_mean      | 10.9     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 14       |
# |    time_elapsed     | 770      |
# |    total_timesteps  | 21388    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.326    |
# |    n_updates        | 203      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 97       |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 14       |
# |    time_elapsed     | 794      |
# |    total_timesteps  | 21767    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.164    |
# |    n_updates        | 207      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 14       |
# |    time_elapsed     | 806      |
# |    total_timesteps  | 21939    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.177    |
# |    n_updates        | 209      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 94.8     |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 14       |
# |    time_elapsed     | 823      |
# |    total_timesteps  | 22210    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.195    |
# |    n_updates        | 212      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 96.5     |
# |    ep_rew_mean      | 11.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 14       |
# |    time_elapsed     | 858      |
# |    total_timesteps  | 22744    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.242    |
# |    n_updates        | 217      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 106      |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 14       |
# |    time_elapsed     | 946      |
# |    total_timesteps  | 24109    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0525   |
# |    n_updates        | 231      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 117      |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 14       |
# |    time_elapsed     | 1024     |
# |    total_timesteps  | 25317    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.132    |
# |    n_updates        | 243      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 121      |
# |    ep_rew_mean      | 11.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 14       |
# |    time_elapsed     | 1062     |
# |    total_timesteps  | 25906    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0501   |
# |    n_updates        | 249      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 15       |
# |    time_elapsed     | 1135     |
# |    total_timesteps  | 27051    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.129    |
# |    n_updates        | 260      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 133      |
# |    ep_rew_mean      | 11.6     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 15       |
# |    time_elapsed     | 1171     |
# |    total_timesteps  | 27600    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.17     |
# |    n_updates        | 265      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 132      |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 15       |
# |    time_elapsed     | 1175     |
# |    total_timesteps  | 27663    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.129    |
# |    n_updates        | 266      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 15       |
# |    time_elapsed     | 1185     |
# |    total_timesteps  | 27818    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.134    |
# |    n_updates        | 268      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 129      |
# |    ep_rew_mean      | 11.3     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 15       |
# |    time_elapsed     | 1208     |
# |    total_timesteps  | 28175    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.107    |
# |    n_updates        | 271      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 120      |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 15       |
# |    time_elapsed     | 1227     |
# |    total_timesteps  | 28463    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.162    |
# |    n_updates        | 274      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 124      |
# |    ep_rew_mean      | 11.4     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 15       |
# |    time_elapsed     | 1275     |
# |    total_timesteps  | 29202    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0428   |
# |    n_updates        | 282      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 123      |
# |    ep_rew_mean      | 11.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 15       |
# |    time_elapsed     | 1289     |
# |    total_timesteps  | 29404    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0836   |
# |    n_updates        | 284      |
# ----------------------------------

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-38c0d959e4f20191" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-38c0d959e4f20191");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
