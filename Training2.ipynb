# %%
# %matplotlib inline
import import_ipynb
from RL_model import RL_model
import os
import gym
import torch as th
import numpy as np
import matplotlib.pyplot as plt
from IPython.core.pylabtools import figsize
from stable_baselines3 import DQN
from stable_baselines3.common.torch_layers import BaseFeaturesExtractor
# Out:
# importing Jupyter notebook from RL_model.ipynb
# importing Jupyter notebook from SV_channel.ipynb
# Covariance matrix:
#  [[ 1.3346+0.j     -0.6699+0.3489j  0.131 +0.3869j -0.6994-0.3916j]
#  [-0.6699-0.3489j  1.1449+0.j     -0.6021-0.3801j  0.3288+0.8685j]
#  [ 0.131 -0.3869j -0.6021+0.3801j  0.8438+0.j     -0.4426-0.3363j]
#  [-0.6994+0.3916j  0.3288-0.8685j -0.4426+0.3363j  0.9901+0.j    ]]
#
# Matrix rank: 4
# importing Jupyter notebook from HybridMassiveMIMO.ipynb
# Channel capacity estimation for SNR 70 dB: 11.198521824187482 bps/Hz

# %%
qam16_gray = {"0000": np.complex128(-3 + 3j), "0001": np.complex128(-3 + 1j), "0010": np.complex128(-3 - 3j), \
              "0011": np.complex128(-3 - 1j), "0100": np.complex128(-1 + 3j), "0101": np.complex128(-1 + 1j), \
              "0110": np.complex128(-1 - 3j), "0111": np.complex128(-1 - 1j), "1000": np.complex128(3 + 3j), \
              "1001": np.complex128(3 + 1j), "1010": np.complex128(3 - 3j), "1011": np.complex128(3 - 1j), \
              "1100": np.complex128(1 + 3j), "1101": np.complex128(1 + 1j), "1110": np.complex128(1 - 3j), \
              "1111": np.complex128(1 - 1j)}

# Training by DQN
env = RL_model(N_s = 4,
                N_rf = 4,
                N_tx = (4, 4),
                N_rx = (2, 2),
                N_ofdm = 4,
                N_ifft = 512,
                N_c = 450,
                N_gi = 64,
                mapping = qam16_gray,
                N_p = 4,
                static_chan = False,
                SNR = (20, 70),
                cl = 5,
                rays = 2,
                reward_param = 5)
env.reset()

models_dir = "models/DQN2"
logdir = "logs"

if not os.path.exists(models_dir):
    os.makedirs(models_dir)

time_steps = 50000

model = DQN.load(f"{models_dir.replace('2', '1')}/20000")

model.set_env(env)

model.learn(total_timesteps = time_steps, tb_log_name = "DQN2", reset_num_timesteps = False)

model.save(f"{models_dir}/{time_steps}")
# Out:
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to logs\DQN2_0
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 126      |
# |    ep_rew_mean      | 11.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 13       |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 30086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 119      |
# |    ep_rew_mean      | 11       |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 13       |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 30168    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.57     |
# |    n_updates        | 291      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 133      |
# |    ep_rew_mean      | 10.7     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 13       |
# |    time_elapsed     | 119      |
# |    total_timesteps  | 31653    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 306      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 132      |
# |    ep_rew_mean      | 10.5     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 13       |
# |    time_elapsed     | 136      |
# |    total_timesteps  | 31872    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0602   |
# |    n_updates        | 308      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 13       |
# |    time_elapsed     | 203      |
# |    total_timesteps  | 32789    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0769   |
# |    n_updates        | 317      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 142      |
# |    ep_rew_mean      | 10.2     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 13       |
# |    time_elapsed     | 298      |
# |    total_timesteps  | 34112    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0202   |
# |    n_updates        | 331      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 141      |
# |    ep_rew_mean      | 9.91     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 13       |
# |    time_elapsed     | 321      |
# |    total_timesteps  | 34415    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0558   |
# |    n_updates        | 334      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 138      |
# |    ep_rew_mean      | 9.59     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 13       |
# |    time_elapsed     | 343      |
# |    total_timesteps  | 34734    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.161    |
# |    n_updates        | 337      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 147      |
# |    ep_rew_mean      | 9.22     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 13       |
# |    time_elapsed     | 423      |
# |    total_timesteps  | 35857    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0141   |
# |    n_updates        | 348      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 148      |
# |    ep_rew_mean      | 8.78     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 13       |
# |    time_elapsed     | 454      |
# |    total_timesteps  | 36285    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0562   |
# |    n_updates        | 352      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 155      |
# |    ep_rew_mean      | 8.7      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 13       |
# |    time_elapsed     | 533      |
# |    total_timesteps  | 37386    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.024    |
# |    n_updates        | 363      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | 8.37     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 13       |
# |    time_elapsed     | 572      |
# |    total_timesteps  | 37911    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0476   |
# |    n_updates        | 369      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 160      |
# |    ep_rew_mean      | 8.34     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 13       |
# |    time_elapsed     | 600      |
# |    total_timesteps  | 38320    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.144    |
# |    n_updates        | 373      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | 8.19     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 13       |
# |    time_elapsed     | 611      |
# |    total_timesteps  | 38471    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0156   |
# |    n_updates        | 374      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 150      |
# |    ep_rew_mean      | 7.71     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 13       |
# |    time_elapsed     | 665      |
# |    total_timesteps  | 39222    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.125    |
# |    n_updates        | 382      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 149      |
# |    ep_rew_mean      | 7.45     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 13       |
# |    time_elapsed     | 752      |
# |    total_timesteps  | 40367    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0332   |
# |    n_updates        | 393      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | 7.09     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 13       |
# |    time_elapsed     | 804      |
# |    total_timesteps  | 41085    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0371   |
# |    n_updates        | 400      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | 6.81     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 13       |
# |    time_elapsed     | 895      |
# |    total_timesteps  | 42303    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0238   |
# |    n_updates        | 413      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 149      |
# |    ep_rew_mean      | 6.41     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 13       |
# |    time_elapsed     | 914      |
# |    total_timesteps  | 42592    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0232   |
# |    n_updates        | 415      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 6.35     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 13       |
# |    time_elapsed     | 952      |
# |    total_timesteps  | 43144    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.241    |
# |    n_updates        | 421      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 153      |
# |    ep_rew_mean      | 6.37     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 13       |
# |    time_elapsed     | 959      |
# |    total_timesteps  | 43247    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0158   |
# |    n_updates        | 422      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 150      |
# |    ep_rew_mean      | 5.8      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 13       |
# |    time_elapsed     | 964      |
# |    total_timesteps  | 43317    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0285   |
# |    n_updates        | 423      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 149      |
# |    ep_rew_mean      | 5.52     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 13       |
# |    time_elapsed     | 978      |
# |    total_timesteps  | 43512    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0287   |
# |    n_updates        | 425      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | 5.28     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 13       |
# |    time_elapsed     | 1047     |
# |    total_timesteps  | 44561    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0609   |
# |    n_updates        | 435      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | 5.15     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 13       |
# |    time_elapsed     | 1086     |
# |    total_timesteps  | 45133    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.141    |
# |    n_updates        | 441      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 153      |
# |    ep_rew_mean      | 5.13     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 13       |
# |    time_elapsed     | 1101     |
# |    total_timesteps  | 45344    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0216   |
# |    n_updates        | 443      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 4.89     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 13       |
# |    time_elapsed     | 1113     |
# |    total_timesteps  | 45534    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 445      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 142      |
# |    ep_rew_mean      | 4.96     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 13       |
# |    time_elapsed     | 1134     |
# |    total_timesteps  | 45843    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.031    |
# |    n_updates        | 448      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 151      |
# |    ep_rew_mean      | 4.9      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 14       |
# |    time_elapsed     | 1209     |
# |    total_timesteps  | 46952    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.158    |
# |    n_updates        | 459      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | 5.02     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 14       |
# |    time_elapsed     | 1280     |
# |    total_timesteps  | 48032    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0272   |
# |    n_updates        | 470      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 146      |
# |    ep_rew_mean      | 5.06     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 14       |
# |    time_elapsed     | 1328     |
# |    total_timesteps  | 48719    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.216    |
# |    n_updates        | 477      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 145      |
# |    ep_rew_mean      | 4.99     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 14       |
# |    time_elapsed     | 1345     |
# |    total_timesteps  | 48964    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.119    |
# |    n_updates        | 479      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 157      |
# |    ep_rew_mean      | 5.01     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 14       |
# |    time_elapsed     | 1442     |
# |    total_timesteps  | 50393    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0363   |
# |    n_updates        | 493      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 148      |
# |    ep_rew_mean      | 5.37     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 14       |
# |    time_elapsed     | 1457     |
# |    total_timesteps  | 50631    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0246   |
# |    n_updates        | 496      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 159      |
# |    ep_rew_mean      | 5.43     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 14       |
# |    time_elapsed     | 1560     |
# |    total_timesteps  | 52148    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0162   |
# |    n_updates        | 511      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | 5.36     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 14       |
# |    time_elapsed     | 1590     |
# |    total_timesteps  | 52602    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0456   |
# |    n_updates        | 516      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 148      |
# |    ep_rew_mean      | 5.25     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 14       |
# |    time_elapsed     | 1600     |
# |    total_timesteps  | 52742    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0425   |
# |    n_updates        | 517      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 150      |
# |    ep_rew_mean      | 5.19     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 14       |
# |    time_elapsed     | 1638     |
# |    total_timesteps  | 53291    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0223   |
# |    n_updates        | 522      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 160      |
# |    ep_rew_mean      | 5.23     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 14       |
# |    time_elapsed     | 1717     |
# |    total_timesteps  | 54490    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0234   |
# |    n_updates        | 534      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | 5.34     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 14       |
# |    time_elapsed     | 1808     |
# |    total_timesteps  | 55847    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0254   |
# |    n_updates        | 548      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 161      |
# |    ep_rew_mean      | 5.39     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 14       |
# |    time_elapsed     | 1851     |
# |    total_timesteps  | 56480    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.12     |
# |    n_updates        | 554      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 158      |
# |    ep_rew_mean      | 5.42     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 14       |
# |    time_elapsed     | 1881     |
# |    total_timesteps  | 56905    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 559      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | 5.3      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 14       |
# |    time_elapsed     | 1919     |
# |    total_timesteps  | 57479    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0211   |
# |    n_updates        | 564      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 152      |
# |    ep_rew_mean      | 5.14     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 14       |
# |    time_elapsed     | 1938     |
# |    total_timesteps  | 57782    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0193   |
# |    n_updates        | 567      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 150      |
# |    ep_rew_mean      | 5.11     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 14       |
# |    time_elapsed     | 1960     |
# |    total_timesteps  | 58102    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.019    |
# |    n_updates        | 571      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | 4.84     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 14       |
# |    time_elapsed     | 2011     |
# |    total_timesteps  | 58836    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0323   |
# |    n_updates        | 578      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 157      |
# |    ep_rew_mean      | 4.93     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 14       |
# |    time_elapsed     | 2025     |
# |    total_timesteps  | 59039    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0229   |
# |    n_updates        | 580      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 163      |
# |    ep_rew_mean      | 4.91     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 14       |
# |    time_elapsed     | 2076     |
# |    total_timesteps  | 59793    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0312   |
# |    n_updates        | 587      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 164      |
# |    ep_rew_mean      | 4.86     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 14       |
# |    time_elapsed     | 2154     |
# |    total_timesteps  | 60960    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0169   |
# |    n_updates        | 599      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 164      |
# |    ep_rew_mean      | 4.81     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 14       |
# |    time_elapsed     | 2193     |
# |    total_timesteps  | 61541    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0181   |
# |    n_updates        | 605      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 165      |
# |    ep_rew_mean      | 5.08     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 14       |
# |    time_elapsed     | 2215     |
# |    total_timesteps  | 61873    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0193   |
# |    n_updates        | 608      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 167      |
# |    ep_rew_mean      | 5.24     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 14       |
# |    time_elapsed     | 2236     |
# |    total_timesteps  | 62187    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 611      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 169      |
# |    ep_rew_mean      | 5.32     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 14       |
# |    time_elapsed     | 2275     |
# |    total_timesteps  | 62754    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0278   |
# |    n_updates        | 617      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | 5.37     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 14       |
# |    time_elapsed     | 2370     |
# |    total_timesteps  | 64164    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0881   |
# |    n_updates        | 631      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 166      |
# |    ep_rew_mean      | 5.18     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 14       |
# |    time_elapsed     | 2404     |
# |    total_timesteps  | 64645    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.025    |
# |    n_updates        | 636      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 163      |
# |    ep_rew_mean      | 5.21     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 14       |
# |    time_elapsed     | 2427     |
# |    total_timesteps  | 64980    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0237   |
# |    n_updates        | 639      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 172      |
# |    ep_rew_mean      | 5.33     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 14       |
# |    time_elapsed     | 2508     |
# |    total_timesteps  | 66198    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0235   |
# |    n_updates        | 651      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 162      |
# |    ep_rew_mean      | 5.15     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 14       |
# |    time_elapsed     | 2533     |
# |    total_timesteps  | 66563    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0167   |
# |    n_updates        | 655      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 162      |
# |    ep_rew_mean      | 4.85     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 14       |
# |    time_elapsed     | 2550     |
# |    total_timesteps  | 66816    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0736   |
# |    n_updates        | 658      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 149      |
# |    ep_rew_mean      | 4.96     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 14       |
# |    time_elapsed     | 2568     |
# |    total_timesteps  | 67079    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0219   |
# |    n_updates        | 660      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 147      |
# |    ep_rew_mean      | 5.01     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 14       |
# |    time_elapsed     | 2585     |
# |    total_timesteps  | 67336    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.135    |
# |    n_updates        | 663      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 148      |
# |    ep_rew_mean      | 5.02     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 14       |
# |    time_elapsed     | 2596     |
# |    total_timesteps  | 67515    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.17     |
# |    n_updates        | 665      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 144      |
# |    ep_rew_mean      | 5.12     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 14       |
# |    time_elapsed     | 2609     |
# |    total_timesteps  | 67695    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0917   |
# |    n_updates        | 666      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | 5.04     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 14       |
# |    time_elapsed     | 2626     |
# |    total_timesteps  | 67942    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0995   |
# |    n_updates        | 669      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 125      |
# |    ep_rew_mean      | 5.03     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 14       |
# |    time_elapsed     | 2652     |
# |    total_timesteps  | 68317    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.163    |
# |    n_updates        | 673      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 122      |
# |    ep_rew_mean      | 5.04     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 14       |
# |    time_elapsed     | 2674     |
# |    total_timesteps  | 68634    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0175   |
# |    n_updates        | 676      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 123      |
# |    ep_rew_mean      | 5.09     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 2        |
# |    time_elapsed     | 16778    |
# |    total_timesteps  | 69203    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0234   |
# |    n_updates        | 682      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 131      |
# |    ep_rew_mean      | 5.31     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 2        |
# |    time_elapsed     | 16874    |
# |    total_timesteps  | 70542    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0405   |
# |    n_updates        | 695      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 132      |
# |    ep_rew_mean      | 5.44     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 2        |
# |    time_elapsed     | 16902    |
# |    total_timesteps  | 70954    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0219   |
# |    n_updates        | 699      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 135      |
# |    ep_rew_mean      | 5.32     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 2        |
# |    time_elapsed     | 16944    |
# |    total_timesteps  | 71560    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0426   |
# |    n_updates        | 705      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 143      |
# |    ep_rew_mean      | 5.27     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 2        |
# |    time_elapsed     | 17056    |
# |    total_timesteps  | 73125    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0264   |
# |    n_updates        | 721      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 143      |
# |    ep_rew_mean      | 5.26     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 2        |
# |    time_elapsed     | 17069    |
# |    total_timesteps  | 73306    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0221   |
# |    n_updates        | 723      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 138      |
# |    ep_rew_mean      | 5.48     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 2        |
# |    time_elapsed     | 17090    |
# |    total_timesteps  | 73590    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0183   |
# |    n_updates        | 725      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 130      |
# |    ep_rew_mean      | 5.58     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 2        |
# |    time_elapsed     | 17119    |
# |    total_timesteps  | 73988    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0323   |
# |    n_updates        | 729      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 137      |
# |    ep_rew_mean      | 5.5      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 2        |
# |    time_elapsed     | 17208    |
# |    total_timesteps  | 75254    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.295    |
# |    n_updates        | 742      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 156      |
# |    ep_rew_mean      | 5.23     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 2        |
# |    time_elapsed     | 17365    |
# |    total_timesteps  | 77455    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.034    |
# |    n_updates        | 764      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 164      |
# |    ep_rew_mean      | 5.18     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 2        |
# |    time_elapsed     | 17448    |
# |    total_timesteps  | 78563    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0217   |
# |    n_updates        | 775      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 161      |
# |    ep_rew_mean      | 5.21     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 2        |
# |    time_elapsed     | 17468    |
# |    total_timesteps  | 78837    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0339   |
# |    n_updates        | 778      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 154      |
# |    ep_rew_mean      | 5.17     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 2        |
# |    time_elapsed     | 17525    |
# |    total_timesteps  | 79609    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0256   |
# |    n_updates        | 786      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 153      |
# |    ep_rew_mean      | 5.17     |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 2        |
# |    time_elapsed     | 17551    |
# |    total_timesteps  | 79968    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    loss             | 0.0292   |
# |    n_updates        | 789      |
# ----------------------------------

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6006 (pid 14532), started 7:11:49 ago. (Use '!kill 14532' to kill it.)
#       <iframe id="tensorboard-frame-62bff3a1aa5f6ef3" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-62bff3a1aa5f6ef3");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
